# %% [markdown]
# ### Test News Scope Identification Prompt with LLM Agent

# %%
import sys,os,time
from pathlib import Path
#import instructor
from pydantic import BaseModel
sys.path.insert(0, '../libs')
# Import SimpleLLMAgent from libs directory
PROJECT_ROOT = Path('..').resolve()
LIBS_DIR = PROJECT_ROOT / "libs"
PROMPTS_DIR = PROJECT_ROOT / "prompts"

for subdir in (PROJECT_ROOT, LIBS_DIR):
    if str(subdir) not in sys.path:
        sys.path.insert(0, str(subdir))
        
from pydantic import BaseModel, Field
# Import our general LLM factory
from llm_factory_openai import LLMAgent
from utils import read_json
from dotenv import load_dotenv

from src.run_llm_article_level import _build_batch_messages_from_articles
# Load environment variables from .env file
load_dotenv('../.env')
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("OPENAI_API_KEY not found in environment variables. Please check your .env file.")

# %%
# ---------------------------------------------------------------------------
# Local imports (resolved after sys.path modification)
# ---------------------------------------------------------------------------

from llm_factory_openai import BatchAsyncLLMAgent  # type: ignore
from prompt_utils import load_prompt, format_messages  # type: ignore
from utils import read_json  # type: ignore
from prompts.schemas import PROMPT_REGISTRY  # noqa: E402  (after path tweaks)

# %% [markdown]
# #### Load some data

# %%
## set up global paths 
input_data_dir = Path("//data2/CommercialData/Factiva_Repository")
test_file = input_data_dir / "2025" / "2025_articles.json"
data = read_json(test_file)

# %%
print(data[0]['body'])
# Out:
# En ese sentido ha señalado que los operadores del sistema eléctrico europeo están trabajando «no sólo para esclarecer lo ocurrido, sino también para dar apoyo en la restauración del sistema». «Por el momento el mensaje más importante es de paciencia y de seguir las instrucciones de protección civil», ha añadido Ribera. La responsable de Transición Limpia y Competencia de la Comisión Europea ha confirmado que el apagón ha afectado a España y Portugal y que ha podido causar alguna incidencia menor en el sur de Francia. Para llevar a cabo una recuperación de su sistema eléctrico, Ribera ha explicado que Portugal se ha desconectado de la red española y que España está apoyando su generación eléctrica con energía hidroeléctrica y térmica. En un comunicado, la Comisión Europea ha afirmado que se mantiene en contacto con Madrid y Lisboa y con la Red Europea de Gestores de Redes de Transporte de Electricidad para entender la causa y el impacto del apagón. La Comisión seguirá monitorizando la situación y asegurar que haya una comunicación fluida de información entre las partes. «Según la legislación europea vigente en materia de código de red de emergencia y restauración, existen protocolos para restablecer el funcionamiento del sistema», asegura la institución presidida por la alemana Ursula von der Leyen. La jefa del Ejecutivo comunitario ha publicado un mensaje en el que asegura que ha hablado con el presidente del Gobierno español, Pedro Sánchez, y ha reafirmado el apoyo de la Comisión para monitorizar la situación en la península ibérica. Precisamente esta semana la política alemana viajará a España para atender el Congreso del Partido Popular Europeo, que se celebra el 29 y 30 de abril en Valencia. Una portavoz de Bruselas también ha desmentido un comunicado falso que se atribuía a Von der Leyen, que ha circulado por las redes sociales y que apuntaban a que el apagón se ha producido por «una ola de ciberataques» perpetrados por Rusia.

# %%
task="news_scope_classification"
if task not in PROMPT_REGISTRY:
    raise ValueError(f"Unknown task '{task}'. Available: {list(PROMPT_REGISTRY.keys())}")
prompt_file = PROMPT_REGISTRY[task]["prompt_file"]  # markdown template filename
response_model = PROMPT_REGISTRY[task]["response_model"]  # pydantic schema enforcing the response structure

# Resolve prompt path and load template
prompt_path = PROMPTS_DIR / prompt_file
prompt_template = load_prompt(str(prompt_path)).sections

prompt_template
# Out:
# {'system': 'You are an expert news text analyzer. When given a news article, you must determine whether it is primarily **Local News** or **International News**.  \n\n• **Local News**: Primarily about events, policies, people, or issues within a single country, with domestic focus (e.g., U.S. elections, state policies, local companies’ performance, U.S. sports leagues). Even if foreign aspects are mentioned, the emphasis is on domestic impacts.\n• **International News**: Primarily about relations, conflicts, policies, or events between multiple countries or focused mainly on foreign nations. Covers global affairs, foreign governments, international organizations, wars, diplomacy, cross-border trade, etc.  \n\n**Step by Step Instructions:**\n* Carefully read the news text.\n* Consider where the main **actors, events, and impacts** are located.\n* If the main focus is on domestic events (inside one country) → **Local News**.\n* If the main focus is on global affairs or multiple countries → **International News**.\n* Output only the classification label: **Local News** or **International News**; and a brief **justification**\n\n**Make sure you always respond in English, no matter what the source language is.**',
#  'schema': 'Respond **only** in JSON with the following keys:\n```json\n{\n  "classification": "Local News" | "International News",\n  "justification" : "<In 1-2 sentences, very brief explanation of key reasons that influenced your decision>"\n}\n```',
#  'user': 'Classify the following text into Local News or International News:\n{TEXT}'}

# %% [markdown]
# #### Set up llm agent

# %%
netmind_api_key = os.getenv("Netmind_api_key")
if not netmind_api_key:
    raise ValueError("Netmind_api_key not found in environment variables. Please check your .env file.")

# %%
local_model_args = {"model":"Qwen/Qwen3-8B",
                    "base_url":"https://api.netmind.ai/inference-api/openai/v1",
                    "temperature":0.0,
                    "api_key":netmind_api_key
                    }
openai_agent = LLMAgent(**local_model_args)

result = openai_agent.test_connection()
print(f"OpenAI test result: {result}")
# Out:
# OpenAI test result: Hello! Yes, I'm here and ready to help. How can I assist you today? 😊

# %%
from prompts.schemas import NewsScopeClassificationResponse

# %%
batch_messages, batch_ids = _build_batch_messages_from_articles(data[:100], prompt_template,max_article_length=1000)
batch_messages[0]
# Out:
# [{'role': 'system',
#   'content': 'You are an expert news text analyzer. When given a news article, you must determine whether it is primarily **Local News** or **International News**.  \n\n• **Local News**: Primarily about events, policies, people, or issues within a single country, with domestic focus (e.g., U.S. elections, state policies, local companies’ performance, U.S. sports leagues). Even if foreign aspects are mentioned, the emphasis is on domestic impacts.\n• **International News**: Primarily about relations, conflicts, policies, or events between multiple countries or focused mainly on foreign nations. Covers global affairs, foreign governments, international organizations, wars, diplomacy, cross-border trade, etc.  \n\n**Step by Step Instructions:**\n* Carefully read the news text.\n* Consider where the main **actors, events, and impacts** are located.\n* If the main focus is on domestic events (inside one country) → **Local News**.\n* If the main focus is on global affairs or multiple countries → **International News**.\n* Output only the classification label: **Local News** or **International News**; and a brief **justification**\n\n**Make sure you always respond in English, no matter what the source language is.**\n\nRespond **only** in JSON with the following keys:\n```json\n{\n  "classification": "Local News" | "International News",\n  "justification" : "<In 1-2 sentences, very brief explanation of key reasons that influenced your decision>"\n}\n```'},
#  {'role': 'user',
#   'content': 'Classify the following text into Local News or International News:\nBruselas asegura que «no hay indicios de un boicot o un ciberataque» Bruselas tiene su vista puesta en el apagón que ha afectado este lunes a España y Portugal. La vicepresidenta de la Comisión Europea, Teresa Ribera, ha pedido máxima ante este incidente y ha asegurado que, por el momento, «no hay nada que nos permita afirmar que ha habido un boicot o un ciberataque». El Ejecutivo comunitario está en contacto con las autoridades de los dos países para dar seguimiento y «apoyo», en un momento en el que la máxima prioridad es recuperar la normalidad del sistema eléctrico de la península. Los servicios técnicos de Bruselas llevan haciendo un seguimiento de la situación desde que han recibido el aviso de España y Portugal, a las 12.45 horas de este lunes. «Se trata de un episodio histórico y nos estamos coordinando para que el servicio se pueda restaurar cuanto antes», ha apuntado la vicepresidenta. En ese sentido ha señalado que los operadores del sistema eléctrico europeo están trabajand'}]

# %%
for messages in batch_messages:
    print("----------------------------")
    print("----------------------------")
    structured_result = openai_agent.get_response_content(messages, response_format=NewsScopeClassificationResponse)
    print("Structured output label:", structured_result.classification)
    print("Structured output Justification:", structured_result.justification)
    print("-------")
    print(messages[1]['content'])
    print("\n\n")
    time.sleep(1)
# Out:
# ----------------------------
# ----------------------------
# Structured output label: International News
# Structured output Justification: The text discusses a power outage affecting Spain and Portugal, with the European Commission (Brussels) involved in coordination. While the event is in Spain and Portugal, the focus is on international cooperation and the European Union's response, making it international in scope.
# -------
# Classify the following text into Local News or International News:
# Bruselas asegura que «no hay indicios de un boicot o un ciberataque» Bruselas tiene su vista puesta en el apagón que ha afectado este lunes a España y Portugal. La vicepresidenta de la Comisión Europea, Teresa Ribera, ha pedido máxima ante este incidente y ha asegurado que, por el momento, «no hay nada que nos permita afirmar que ha habido un boicot o un ciberataque». El Ejecutivo comunitario está en contacto con las autoridades de los dos países para dar seguimiento y «apoyo», en un momento en el que la máxima prioridad es recuperar la normalidad del sistema eléctrico de la península. Los servicios técnicos de Bruselas llevan haciendo un seguimiento de la situación desde que han recibido el aviso de España y Portugal, a las 12.45 horas de este lunes. «Se trata de un episodio histórico y nos estamos coordinando para que el servicio se pueda restaurar cuanto antes», ha apuntado la vicepresidenta. En ese sentido ha señalado que los operadores del sistema eléctrico europeo están trabajand
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article focuses on General Motors' financial performance and strategic decisions within the United States, including domestic tariffs and corporate responses, indicating a domestic focus.
# -------
# Classify the following text into Local News or International News:
# GM posts strong Q1 results, but will reassess expectations for 2025 due to auto tariffs General Motors posted strong financial results for its first quarter Tuesday, but says it will reassess its expectations for 2025 due to auto tariffs.
#
# The automaker is pushing back its conference call to discuss its guidance and quarterly results until Thursday, so that it can assess potential tariff changes. GM said that its initial full-year financial forecast doesn't contemplate the potential impact of tariffs. In January the company announced  that it anticipated 2025 adjusted earnings in a range of $11 to $12 per share .
#
# Late Monday The Wall Street Journal reported that President Donald Trump will possibly dial back automotive tariffs, with anonymous sources claiming that he’ll stop duties on foreign-made cars from piling on top of other tariffs he implemented and easing some levies on foreign parts used to make cars in the U.S.
#
# White House press secretary Karoline Leavitt said Tuesday morni
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: International News
# Structured output Justification: The text discusses the impact of U.S. tariffs on Chinese manufacturing, leading Chinese factories to seek new markets in Latin America and Europe, involving multiple countries and global trade dynamics.
# -------
# Classify the following text into Local News or International News:
# Fábricas chinas pausan producción y buscan mercados en Latinoamérica y Europa Haga clic para ver la imagen.
#
# * Los aranceles de Estados Unidos fuerzan un freno en buena parte de las fábricas chinas. * Estas empresas están buscando nuevos mercados en Latinoamérica y Europa.
#
# * También prueban con marketing digital: el livestreaming impulsa las ventas internas ante crisis.
#
# La imposición de fuertes aranceles por parte de Estados Unidos está comenzando a tener un efecto palpable en la actividad manufacturera china, obligando a las fábricas a pausar sus líneas de producción y a explorar nuevos horizontes comerciales, principalmente en Latinoamérica y Europa, según reportan distintos medios internacionales este lunes 28 de abril.
#
# Esta situación, desencadenada por el aumento en los gravámenes a los productos chinos de más del 100%, está generando una merma importante en los pedidos y afectando el panorama laboral del gigante asiático.
#
# Impacto de los aranceles estadounidenses
#
# La duplicaci
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: International News
# Structured output Justification: The text describes a massive blackout affecting the entire Iberian Peninsula, involving multiple countries (Spain and Portugal), and discusses cross-border impacts on infrastructure and services, indicating a focus on international scope.
# -------
# Classify the following text into Local News or International News:
# Aún quedan tres trenes llenos de personas atrapadas debido al apagón masivo en la Península: “Va a ser una noche larga” Miles de personas han requerido la asistencia de las Fuerzas y Cuerpos de Seguridad del Estado ante la caída total de las redes eléctricas en el país, después de que desapareciesen “súbitamente” 15 gigavatios - el 60% de la demanda eléctrica en ese momento - en cinco segundos A las 12:33 de este lunes 28 de abril, un apagón masivo  se desató en toda la Península Ibérica, dejando a millones de ciudadanos sin suministro eléctrico y poniendo en jaque a servicios esenciales como hospitales, comisarías y sistemas de emergencias y a las personas que dependen de los mismos. Tanto la red eléctrica, como las comunicaciones, como los servicios de transporte, especialmente el sistema ferroviario - que tuvo que detenerse en su totalidad - vieron su funcionamiento interrumpido repentinamente: en cinco segundos, 15 gigavatios (el 60% de la demanda energética en ese momento) desapar
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: International News
# Structured output Justification: The article discusses trade tensions between China and the U.S., involving global economic impacts and international organizations like the WTO, indicating a focus on international relations and global affairs.
# -------
# Classify the following text into Local News or International News:
# China's trade countermeasures are justified self-defense against US bullying, expert says This photo taken on March 29, 2023 shows the White House in Washington, D.C., the United States. [Photo/Xinhua]
#
# China's recent trade countermeasures against U.S. tariff hikes are a reasonable and legitimate act of self-defense, Liu Yingkui, a researcher at the Academy of China Council for the Promotion of International Trade, told China.org.cn in an exclusive interview. Liu said that these tariffs, unprecedented in scale and reach since World War II, could disrupt global supply chains and potentially backfire, unleashing global economic turmoil. The remarks came after the U.S. announcement of country-to-country "reciprocal tariffs," including a 34% levy on China that escalated U.S. tariffs on Chinese goods to 54%. In response, China filed a lawsuit with the WTO and announced an additional 34% tariff on all U.S. imports.
#
# Just days after the U.S. announcement, global market tumbled as tariff-fuele
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: International News
# Structured output Justification: The article discusses Italy's economic performance and mentions international factors like U.S. tariffs and the IMF's global economic forecasts, indicating a focus on cross-border economic relations and global institutions.
# -------
# Classify the following text into Local News or International News:
# Italie: hausse du PIB de 0,3% au premier trimestre L'Italie a vu son produit intérieur brut (PIB) augmenter de 0,3% au premier trimestre 2025 par rapport au précédent, grâce à une progression de tous les secteurs à l'exception de celui des services, a annoncé mercredi l'Institut national des statistiques (Istat).
#
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: International News
# Structured output Justification: The article discusses global trade tensions between the U.S. and China, impacts on gold prices, and mentions international economic implications, indicating a focus on international affairs.
# -------
# Classify the following text into Local News or International News:
# Oro en máximos históricos al subir tono de guerra comercial El precio del oro subió casi 3% hasta alcanzar un máximo histórico el jueves, ya que la caída del dólar y la escalada de la guerra comercial entre Estados Unidos y China impulsaron a los inversionistas a refugiarse en el metal precioso.
#
# El oro al contado subió 2.6% a 3,160.82 dólares la onza, después de alcanzar un máximo histórico de 3,171.49 dólares más temprano en la sesión. Los futuros del oro estadounidense subieron 3% y se situaron en 3,194.2 dólares.
#
# El presidente de Estados Unidos, Donald Trump, dijo el miércoles que rebajaría temporalmente los fuertes aranceles a decenas de países, pero aumentó el arancel a China al 125% desde el 104 por ciento.
#
# “El oro recupera su atractivo como refugio seguro y vuelve a encaminarse hacia nuevos máximos históricos”, dijo Nikos Tzabouras, analista jefe de Mercados de Tradu.com.
#
# "Sin embargo, las perspectivas de acuerdos con los socios comerciales suponen un riesgo importante para
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article discusses the expansion of a local service (Bus en +) in specific communes within the Gironde department, focusing on domestic social services and community impact rather than international relations or global events.
# -------
# Classify the following text into Local News or International News:
# Conseil général de la Gironde - Le Bus en + présent dans deux nouvelles communes du Nord-Libournais : Bayas et Lagorce Access the original document here
#
# Le Bus en + présent dans deux nouvelles communes du Nord-Libournais : Bayas et Lagorce * Accueil
#
# * Espace Presse
#
# * Le Bus en + présent dans deux nouvelles communes du Nord-Libournais : Bayas et Lagorce
#
# 18/04/2025
#
# Communiqué de presse
#
# Le Bus en + présent dans deux nouvelles communes du Nord-Libournais : Bayas et Lagorce
#
# Le Département est en charge de l'action sociale, la lutte contre l'exclusion et l'amélioration des conditions de vie. Il agit pour la protection de l'enfance, la santé (PMI et adultes), l'insertion, l'aide aux jeunes, le logement, le soutien aux personnes en situation de handicap et/ou âgées ainsi que les personnes en situation de précarité.
#
# C'est pourquoi, à l'image des Maisons du Département des Solidarités, le Bus en + offre ces services au plus près des habitants sur leur territoire.
#
# Le Bus en + étend son i
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article focuses on environmental impact and transportation policies within Santiago, Chile, discussing local initiatives and data specific to the city's public transport system.
# -------
# Classify the following text into Local News or International News:
# «Primer Informe de Electromovilidad» revela impacto ambiental de buses eléctricos en Santiago En el marco del Día de la Tierra, el Directorio de Transporte Público Metropolitano dio a conocer los datos del documento que recopila el impacto económico, ambiental y social de los buses en la capital.
#
# Gracias a la incorporación de “buses amigables” de la mano con la llegada de la electromovilidad al transporte público, el sistema Red Movilidad es responsable de tan solo el 3,3% de las emisiones de CO2 del transporte en Santiago, mientras que automóviles y motocicletas particulares generan el 90%. Esos son algunos de los datos que contiene el “Primer Informe de Electromovilidad”, que el Directorio de Transporte Público Metropolitano (DTPM) elaboró a ocho años de la incorporación de los primeros modelos eléctricos al sistema, y que posicionan a la capital como la ciudad con más vehículos de ese tipo fuera de las ciudades chinas.
#
# Una disminución de un 80% en las emisiones de material particu
#
#
#
# ----------------------------
# ----------------------------
# Structured output label
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: International News
# Structured output Justification: The article discusses global stock market reactions, international trade policies, and potential global trade wars, indicating a focus on international affairs and multiple countries.
# -------
# Classify the following text into Local News or International News:
# Stocks plunge across the globe on tariff fears Dollar and oil prices dive, while bond markets rally, as traders bet Trump will push US into recession
#
# STOCK markets around the world tumbled yesterday, the dollar sank and oil prices plunged after Donald Trump's new global tariffs raised fears of a US recession. Wall Street experienced one of its worst days in years, with a sell-off in equities wiping nearly $2 trillion (£1.5trillion) off America's most valuable companies in the aftermath of what the US president called "liberation day".
#
# Mr Trump announced minimum tariffs of 10pc on all imports from around the world, with additional levies of dozens of other countries reaching as high as 50pc. The president argued the tariffs would help make the US rich.
#
# However, rating agency Fitch said the trade policies were "significantly raising US recession risks". World leaders signalled they would respond to Mr Trump's tariffs with levies of their own, suggesting a global trade war that would l
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article focuses on voter concerns and election trends in the Philippines, specifically highlighting domestic issues like job creation, healthcare, and food security, which are relevant to the country's internal political and social landscape.
# -------
# Classify the following text into Local News or International News:
# Voters most likely to support candidates advocating for job creation, healthcare, food security — survey Job creation, healthcare access, and food security top the list of voter concerns ahead of the May 2025 elections, based on the latest Social Weather Stations (SWS) survey commissioned by Stratbase Consultancy.
#
# Conducted from March 15 to 20, the survey found that Filipinos are more inclined to support candidates who advocate for increasing job opportunities (92 percent), strengthening the healthcare system (91 percent), and ensuring food security through agricultural development (91 percent). These were followed by equal access to education (90 percent), workers' rights and OFW welfare (89 percent), reducing poverty and hunger (86 percent), and controlling the prices of basic services and goods (85 percent).
#
# Meanwhile, 82 percent favored candidates addressing the impacts of climate change and enhancing disaster preparedness, as well as those defending national security and soverei
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article discusses the expansion of a Spanish dental company within Spain, specifically in Galicia and Catalonia, focusing on domestic business developments and local clinic openings.
# -------
# Classify the following text into Local News or International News:
# Dental & Company sigue expandiendo su red de clínicas con dos nuevas aperturas en Galicia y Cataluña La compañía sevillana Dental & Company Center, titular de la red de clínicas dentales Dental & Company, acaba de estrenar dos clínicas en Arteixo (A Coruña) y Pineda de Mar (Barcelona), cuyos proyectos adelantó en marzo Alimarket Sanidad y Dependencia. El centro de Arteixo se ubica en la rúa Xeneral Mosquera Palleiro, 1, b.3, en la esquina con avenida del Balneario. Se convierte en su sexta clínica en Galicia, y la segunda en A Coruña, tras la apertura el pasado mes de marzo de otro establecimiento en O Milladoiro (Ames). Además, tiene previsto incorporar otro centro más en Sada (A Coruña ). Sus otras cuatro clínicas gallegas se encuentran en la provincia de Pontevedra, en O Porriño, Marín (abierta a finales de octubre de 2024), Ponteareas (inaugurada en diciembre) y Tui (puesta en marcha a finales de febrero de este año).
#
# Por su parte, el centro de Pineda de Mar se sitúa en carrer Mor
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article focuses on Mexico's domestic policies, agricultural investments, and food sovereignty efforts led by President Claudia Sheinbaum, emphasizing domestic impacts and national goals.
# -------
# Classify the following text into Local News or International News:
# What is Sheinbaum's plan for food sovereignty all about? Thefederal government announced Friday an investment of 83,760 million pesos (about 4,188 million dollars) by 2030 to benefit 750,000 agricultural producers and achieve food sovereignty in the face of US protectionism.
#
# The investment will already reach 53,971 million pesos (about 2,698.5 million dollars) and 300,000 farmers this year, said the Secretary of Agriculture and Rural Development, Julio Berdegué, in the government's morning conference. "We are going to increase the nation's food sovereignty and self-sufficiency, we are going to do it with Mexico's small and small producers. It is perfectly possible to do it, if we give them support in a good way", declared the official together with the president, Claudia Sheinbaum.
#
# The goals towards 2030, when Sheinbaum's six-year term ends, are to raise corn production by 17% to 25 million tons, by 64% that of beans to 1.2 million tons, and to double the rice harvest to reach "almos
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The text focuses on U.S. domestic events, including schedules of U.S. officials, economic indicators, and federal government activities, all within the United States.
# -------
# Classify the following text into Local News or International News:
# Reuters WeekAhead/Monday THE REUTERS DAYBOOK DIARY FOR THE WEEK AHEAD
#
# Monday, April 7, 2025 -----
#
# PRESIDENT TRUMP'S SCHEDULE (early schedule)
#
# Not immediately available.
#
# VICE PRESIDENT VANCE'S SCHEDULE (early schedule)
#
# Not immediately available.
#
# SECRETARY OF STATE MARCO RUBIO'S SCHEDULE (early schedule)
#
# Not immediately available.
#
# FIRST LADY MELANIA TRUMP'S SCHEDULE (early schedule)
#
# Not immediately available.
#
# ECONOMIC INDICATORS AND REPORTS
#
# 10 a.m.: The Conference Board issues Employment Trends for March.
#
# 11 a.m.: The USDA releases weekly U.S. export inspections for grains and oilseeds.
#
# 11:30 a.m.: The Treasury Dept. weekly sale of 3-, 6-month bills.
#
# 3 p.m.: The Federal Reserve issues Consumer Credit for February.
#
# 4 p.m.: The USDA issues its weekly Crop Progress report (first report for 2025).
#
# SUPREME COURT
#
# 9:30 a.m.: Releases orders.
#
# Note: The court next hears oral arguments on April 21.
#
# CONGRESS
#
# THE SENATE
#
# The meeting time is TBA.
#
# Committees
#
# No meetings are sched
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article discusses a local government (Diputación de Toledo) initiative regarding a hotel development project within a specific region (Toledo, Spain), focusing on domestic financial and administrative processes.
# -------
# Classify the following text into Local News or International News:
# La Diputación de Toledo ingresará como mínimo 2,3 millones por el canon que cobrará al futuro hotel de San Juan de Dios El Plan de Viabilidad elaborado para la transformación del antiguo hospital de San Juan de Dios en un hotel prevé que el adjudicatario de la futura concesión hotelera abone a lo largo de la vida del contrato un canon mínimo de 2,32 millones de euros a la Diputación de Toledo , titular del inmueble. Esta cantidad, fijada como parte de la cesión administrativa para el uso del edificio, se ha calculado en base a un 2% de los ingresos brutos estimados durante el periodo completo de explotación. El pliego de condiciones permitirá, no obstante, que los interesados puedan mejorar al alza esa cantidad en sus ofertas. El estudio, que analiza con detalle la inversión necesaria, el modelo de gestión y el potencial turístico de la actuación, contempla un sistema de pago flexible para este canon. De hecho, se abre la puerta a que los licitadores puedan proponer el aplazamiento del
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article focuses on regional politics within Aragón, Spain, discussing financial reforms affecting local provinces and cultural awards within the region, indicating a domestic focus.
# -------
# Classify the following text into Local News or International News:
# Azcón afirma que el futuro de Teruel y de todo Aragón depende de «una reforma objetiva» del modelo de financiación autonómica El presidente del Gobierno de Aragón, Jorge Azcón, ha subrayado que «el futuro de Teruel y del conjunto de Aragón depende de que la próxima reforma de la financiación autonómica se haga de forma objetiva, con respeto a nuestras peculiaridades y con la vista puesta en aquellas provincias que más necesitan del impulso del Estado». Azcón se expresó así durante el discurso que ha pronunciado en el acto institucional por el Día de Aragón que se celebró en la Iglesia de San Pedro de Teruel, donde el director gerente de la Fundación Santa María de Albarracín, Antonio Jiménez Martínez, ha recibido la Medalla al Mérito Cultural del Gobierno de Aragón por su labor de preservación y promoción del patrimonio cultural aragonés, particularmente, de Albarracín.  El jefe del Ejecutivo autonómico ha tildado de «absoluto sin sentido» que en el futuro modelo de financiación «no se
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: International News
# Structured output Justification: The article discusses the impact of the trade war between China and the U.S. on global markets, including effects on Japan and Europe, indicating a focus on international relations and global economic implications.
# -------
# Classify the following text into Local News or International News:
# Los mercados tambalean tras el contraataque de China a EE UU: llevó los aranceles al 125% Las bolsas se agitaron en todo el mundo este viernes tras el último episodio de la guerra comercial que enfrenta a China y Estados Unidos, con Japón y algunos mercados europeos a la baja mientras otros se mantenían firmes.
#
# Seguí la bolsa de valores de Argentina y Nueva York, los mercados de carne y granos, a minuto a minuto en https://www.eldia.com/mercados Los futuros del S&P 500 avanzaron un 0,7% mientras que el promedio industrial Dow Jones subió un 0,4%.
#
# Las crecientes preocupaciones por la guerra comercial del presidente de Estados Unidos, Donald Trump, hicieron que el índice de referencia de Tokio cayera inicialmente más del 5%. Recuperó algo de terreno durante la jornada para cerrar con una caída del 3%.
#
# https://www.eldia.com/nota/2025-4-11-7-13-0-china-y-otro-duro-contraataque-a-ee-uu-que-agrava-la-crisis-mundial-lleva-los-aranceles-al-125--el-mundoChina anunció después el incremento de
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article focuses on a local town council's decision regarding municipal taxes in Peace River, a specific Canadian town, and its impact on local taxpayers and housing policies.
# -------
# Classify the following text into Local News or International News:
# ...
#
# À l’époque, trois députés réunis dans une sous-commission dédiée à la thématique du pénitentiaire ont passé 19 séances à décortiquer les problèmes au sein de l’Office cantonal de la détention (OCD), entendant employés et cadres. Ils on
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article focuses on Hewlett Packard Enterprise's job cuts and financial performance, primarily affecting the U.S. workforce, with specific mention of Texas and Houston locations, indicating a domestic focus.
# -------
# Classify the following text into Local News or International News:
# Spring-based Hewlett Packard to cut 5% of its jobs Hewlett Packard Enterprise, the multinational tech company headquartered in Texas, will cut about 2,500 employees over the next 18 months through layoffs and attrition as part of a plan to reduce operating costs.
#
# HPE, which moved its headquarters to the Houston area from Silicon Valley in 2022, has more than 2,000 employees in the Houston area and more than 60,000 around the world. The planned cuts would represent about 5% of HPE's total workforce. The company did not immediately respond to an inquiry about how many employees in the Houston area would be affected.
#
# In a Thursday earnings call, executives said that while the company had exceeded revenue expectations for the quarter ended Jan. 31, its outlook for the current quarter and full fiscal year is lower than analyst expectations.
#
# HPE on Thursday reported net earnings of $598 million in the quarter ended Jan. 31, compared with $387 million in the same period a year earlier. Rev
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article focuses on a local Spanish company's sponsorship of a local event in San Agustín del Guadalix, with donations and activities centered within Spain, specifically Valencia and the local community.
# -------
# Classify the following text into Local News or International News:
# Cardiva patrocina la Carrera de la Mujer y dona 10.000 euros a la DANA Cardiva, empresa española líder en soluciones tecnológicas para el sector salud, ha reforzado su compromiso con la responsabilidad social al convertirse en patrocinador principal de la octava edición de la carrera de la mujer ‘Andacorre con nosotras’. Como parte de esta iniciativa, la compañía ha donado 10.000 euros a la Fundación Vicente Ferrer para apoyar proyectos de reconstrucción en las zonas afectadas por la DANA en Valencia.
#
# Organizada por el Ayuntamiento de San Agustín del Guadalix, a través de sus concejalías de Deportes e Igualdad, y por el Club Deportivo Nosotras, la prueba se ha consolidado como un referente en la promoción del deporte y la solidaridad. La edición de este año ha contado con distintas modalidades de participación: 11 km, 6 km, una marcha de 6 km y carreras infantiles, logrando una gran acogida entre los asistentes. Los fondos recaudados se destinarán a la reconstrucción de infraestructur
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article focuses on the economic impact of Fortune 500 companies within New Jersey, specifically analyzing employment and wages in the state. The data and analysis are centered on a single U.S. state, indicating a domestic focus.
# -------
# Classify the following text into Local News or International News:
# State of New Jersey Department of Labor & Workforce Development - Labor Market Spotlight - Fortune 500 Companies Access the original document here
#
# Labor Market Spotlight - Fortune 500 Companies OFFICE OF RESEARCH AND INFORMATION
#
# Labor Market Spotlight
#
# The Economic Footprint of
#
# Fortune 500 Firms in New Jersey
#
# Issue No. 25, Volume 3: March 2025
#
# This edition of Labor Market Spotlight examines the economic footprint of Fortune 500 (F500) companies in New Jersey, focusing on employment and wages. The analysis is based on the number of business establishments, which are defined as single-location economic units primarily engaged in one activity.
#
# Data from the first quarter of 2024 reveals that F500 companies maintain 8,700 establishments in New Jersey, collectively employing 409,400 workers-accounting for 11% of the state's private sector employment. These figures highlight the significant role F500 firms play in shaping New Jersey's labor market and economic landscape.
#
# NJ Fortune 50
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: International News
# Structured output Justification: The article discusses the impact of Ukrainian immigrants on Poland's economy, involving cross-border migration and economic relations between two countries.
# -------
# Classify the following text into Local News or International News:
# POLAND: UKRAINIAN IMMIGRANTS HAVE POSITIVE IMPACT ON GDP AND BUDGET Ukrainians pay more to the state budget in taxes than they receive in benefits, a report by the country's National Development Bank (BGK) has concluded.
#
# The research also indicated that Ukrainians - who numbered around 1.5 million, making them by far Poland's largest immigrant group - contributed between 0.5% and 2.4% to Poland's annual GDP growth. The findings come amid renewed debate over Ukrainian immigrants during Poland's ongoing presidential campaign, with one leading candidate claiming they receive more in benefits than they pay in taxes and others also calling for restrictions on benefits.
#
# "The analyses conducted and the review of existing research indicate that the presence of migrants from Ukraine has a positive impact on Polish GDP, the labor market, and the budget situation," writes Mateusz Walewski, chief economist at BGK, which is state-owned bank tasked with supporting national development.
#
# The bank's
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: International News
# Structured output Justification: The article discusses trade tensions between Canada and the U.S., involving tariffs and diplomatic statements from both leaders, indicating a focus on international relations and cross-border economic policies.
# -------
# Classify the following text into Local News or International News:
# Canada opens fire; Trudeau Slams 'really Dumb' U.S. Tariffs, says Trump's plan to force Annexation won't work Prime Minister Justin Trudeau said U.S. President Donald Trump's goal with 25 per cent tariffs on all Canadian products is the "total collapse" of Canada's econ - omy in order to annex the country.
#
# In a fiery speech on the morning the U.S. tariffs and retaliatory Canadian tariffs kicked in, Trudeau said Trump's decision to launch a trade war was a "really dumb thing to do." "It's not in my habit to agree with the Wall Street Journal, but Donald, they point out that even though you're a very smart guy, this is a very dumb thing to do," Trudeau said to Trump.
#
# "There are no winners in a trade war," he added, warning Canadians and Americans that it will be "tough" on everyone.
#
# Trump's order placing a 10 per cent tariff on Canadian energy and a 25 per cent levy on all other imports came into effect at 12:01 a.m. ET on Tuesday. As the U.S. tariffs kicked in, Canada re- sponded wit
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: International News
# Structured output Justification: The article discusses Google's acquisition of a U.S. cybersecurity company, highlighting a major international business deal involving a multinational corporation and its foreign acquisition, which has global implications.
# -------
# Classify the following text into Local News or International News:
# Wiz: La compañía de ciberseguridad se convierte en la mayor compra en la historia de Google InternacionalWiz: La compañía de ciberseguridad se convierte en la mayor compra en la historia de GoogleGoogle compró la empresa de ciberseguridad “Wiz” por US$32 mil millones, convirtiéndose en la adquisición “más grande y más importante” hecha hasta ahora por la compañía multinacional de tecnología.
#
# Emilio Dávila 18 de marzo de 2025
#
# |
#
# 10:22h Compartir en Facebook Compartir en X Compartir en LinkedIn Compartir en Whatsapp Copiar enlace Compartir Guardar artículo Google adquiririó la plataforma Wiz por US$32 mil millones, citando la necesidad de una mayor capacidad de ciberseguridad. (Foto Prensa Libre: AFP) Este martes 18 de marzo, la compañía multinacional de tecnología Google compró la empresa estadounidense de ciberseguridad Wiz por US$32 mil millones, por lo que se trata de la adquisición “más grande y más importante” hecha hasta ahora por Alphabet, la casa matriz de Google con sede en C
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The article focuses on India's Union Budget 2025, including reactions from Indian political leaders and economic policies within the country, indicating a domestic focus.
# -------
# Classify the following text into Local News or International News:
# Union Budget 2025 Reactions: PM Modi, Other NDA Leaders Hail Tax Cuts And Reforms, Oppn Calls It 'Directionless' Budget 2025 Political Reactions: Union Finance Minister Nirmala Sitharaman presented her eighthconsecutive budget for the fiscal year 2025-26 on February 1, exempting yearly income up to Rs 12 lakh from income tax as part of her reformist budget. Sitharaman also laid out a plan for next-generation reforms, including increasing the FDI limit in the insurance industry, simplifying tax regulations, and lowering intermediary charges, all while giving increased budgetary assistance for welfare initiatives.
#
# According to the fiscal consolidation plan, Sitharaman predicted that in the fiscal year 2025–2026, the fiscal deficit will drop to 4.4 percent of GDP. However, following the announcement, reactions began to stream in from the political spectrum.
#
# Leaders of the National Democratic Alliance (NDA) praised the Finance Minister's budget speech as she wrapped it up, calling it "gr
#
#
#
# ----------------------------
# ----------------------------
# Structured output label: Local News
# Structured output Justification: The text discusses India's tax regime, EPF, NPS, and financial policies, focusing on domestic economic and social security measures within India.
# -------
# Classify the following text into Local News or International News:
# You still need EPF, NPS, insurance The huge relief in the new tax regime will enhance take-home pay, spur consumption and reduce the allure of traditional tax-saving investments. However, individuals must continue to invest in Employees’ Provident Fund (EPF), National Pension System (NPS), equity-linked savings schemes (ELSS), term and health insurance for their long-term financial security even if the tax-saving incentive is gone.
#
# As most individuals in India have no social security benefits, the tax-saving instruments have encouraged forced savings and encouraged people to invest for various financial goals. Moreover, the lock-in periods in tax-saving instruments have forced a disciplined approach to investing and getting compounding returns. Employees’ Provident Fund
#
# For most salaried employees, EPF is an ideal way to save for retirement provided the subscriber doesn’t withdraw the corpus at every job change. While EPF is mandatory for those with basic pay of `15,000, it is option
#
#
#
# ----------------------------
# ----------------------------
# Structured output label